# %% [markdown]
# # RL Trading based on GRU

# %%
import torch
import torch.nn as nn
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# %%
# def setup_seed(seed):
#     torch.manual_seed(seed)
#     torch.cuda.manual_seed_all(seed)
#     np.random.seed(seed)
#     random.seed(seed)
#     torch.backends.cudnn.deterministic = True
# # 设置随机数种子
# setup_seed(20)

# %% [markdown]
# ## 1. Loading data and data preprocessing

# %%
raw_prices = pd.read_csv("BTC.csv", header=None)
prices = np.array(raw_prices[1])
OFFSET = 100 #数据起始点
M = 10  #输入网络的历史窗口的大小，用于在每个时间步更新权重的历史大小
T = 2000 #交易者输入的时间序列长度
N = 600  #验证集大小
prices = prices[OFFSET:OFFSET+M+T+N+1]
# asset_returns = torch.tensor(np.log(prices[1:]) - np.log(prices[:-1])).to(torch.float32)
# asset_returns = torch.tensor((prices[1:] - prices[:-1]) / prices[:-1]).to(torch.float32)
asset_returns = torch.tensor(prices[1:] - prices[:-1]).to(torch.float32)
print('asset_returns',asset_returns)
scaler = StandardScaler()
normalized_asset_returns = torch.tensor(scaler.fit_transform(asset_returns[:M+T][:, None])[:, 0]).to(torch.float32)
# Out:
# asset_returns tensor([ 1.7000e-01, -7.0600e+00,  4.4730e+01,  ..., -6.4793e+02,
#          8.9026e+02,  1.6336e+03])

# %% [markdown]
# ## 2. Create NN model

# %%
class GRURL(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super(GRURL, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers

        self.gru = nn.GRU(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
        
    def init_hidden(self, batch_size, use_gpu=True):
        if use_gpu: return torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_().cuda()
        else: return torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_()

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_().cuda()
        out, (hn) = self.gru(x, (h0.detach()))
        out = self.fc(out[:, -1, :])
        return torch.tanh(out)

# %%
input_dim = 1
hidden_dim = 64
num_layers = 2
output_dim = 1
use_gpu = torch.cuda.is_available()
device = torch.device("cuda" if use_gpu else "cpu")
model = GRURL(input_dim=input_dim, hidden_dim=hidden_dim, output_dim=output_dim, num_layers=num_layers).to(device)
print(model)
# Out:
# GRURL(
#   (gru): GRU(1, 64, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
# )

# %% [markdown]
# ## 3. Train the model

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
rewards = []
max_iter = 1000
miu = 1
delta = 0.04
eps = 1e-6

# %%
for epoch in range(max_iter):
    optimizer.zero_grad()
    Ft = torch.zeros(T).to(normalized_asset_returns.device)
    for i in range(1, T):
        data = normalized_asset_returns[i-1:i+M-1]
        input = data.view(1,M,1).to(device)
        Ft[i] = model(input)
    returns = miu * (Ft[:T-1] * asset_returns[M:M+T-1]) - (delta * torch.abs(Ft[1:] - Ft[:T-1]))
    expected_return = torch.mean(returns, dim=-1)
    std_return = torch.std(returns, dim=-1)
    sharpe = expected_return / (torch.sqrt(std_return) + eps)
    (-1 * sharpe).backward()
    optimizer.step()
    rewards.append(sharpe.detach().cpu())
    Cum_returns = returns.cumsum(dim=-1)
    print("Epoch ", epoch, "Sharpe: ", sharpe.detach().cpu())
print('Cum_return_train',Cum_returns[-1])
# Out:
# Epoch  0 Sharpe:  tensor(-0.0909)
# Epoch  1 Sharpe:  tensor(-0.0626)
# Epoch  2 Sharpe:  tensor(-0.0224)
# Epoch  3 Sharpe:  tensor(0.0475)
# Epoch  4 Sharpe:  tensor(0.1011)
# Epoch  5 Sharpe:  tensor(0.1219)
# Epoch  6 Sharpe:  tensor(0.1370)
# Epoch  7 Sharpe:  tensor(0.1500)
# Epoch  8 Sharpe:  tensor(0.1618)
# Epoch  9 Sharpe:  tensor(0.1727)
# Epoch  10 Sharpe:  tensor(0.1832)
# Epoch  11 Sharpe:  tensor(0.1934)
# Epoch  12 Sharpe:  tensor(0.2034)
# Epoch  13 Sharpe:  tensor(0.2133)
# Epoch  14 Sharpe:  tensor(0.2233)
# Epoch  15 Sharpe:  tensor(0.2334)
# Epoch  16 Sharpe:  tensor(0.2437)
# Epoch  17 Sharpe:  tensor(0.2543)
# Epoch  18 Sharpe:  tensor(0.2652)
# Epoch  19 Sharpe:  tensor(0.2766)
# Epoch  20 Sharpe:  tensor(0.2885)
# Epoch  21 Sharpe:  tensor(0.3010)
# Epoch  22 Sharpe:  tensor(0.3142)
# Epoch  23 Sharpe:  tensor(0.3284)
# Epoch  24 Sharpe:  tensor(0.3435)
# Epoch  25 Sharpe:  tensor(0.3598)
# Epoch  26 Sharpe:  tensor(0.3774)
# Epoch  27 Sharpe:  tensor(0.3963)
# Epoch  28 Sharpe:  tensor(0.4168)
# Epoch  29 Sharpe:  tensor(0.4386)
# Epoch  30 Sharpe:  tensor(0.4616)
# Epoch  31 Sharpe:  tensor(0.4855)
# Epoch  32 Sharpe:  tensor(0.5097)
# Epoch  33 Sharpe:  tensor(0.5336)
# Epoch  34 Sharpe:  tensor(0.5565)
# Epoch  35 Sharpe:  tensor(0.5781)
# Epoch  36 Sharpe:  tensor(0.5981)
# Epoch  37 Sharpe:  tensor(0.6168)
# Epoch  38 Sharpe:  tensor(0.6344)
# Epoch  39 Sharpe:  tensor(0.6512)
# Epoch  40 Sharpe:  tensor(0.6673)
# Epoch  41 Sharpe:  tensor(0.6831)
# Epoch  42 Sharpe:  tensor(0.6990)
# Epoch  43 Sharpe:  tensor(0.7153)
# Epoch  44 Sharpe:  tensor(0.7328)
# Epoch  45 Sharpe:  tensor(0.7517)
# Epoch  46 Sharpe:  tensor(0.7723)
# Epoch  47 Sharpe:  tensor(0.7937)
# Epoch  48 Sharpe:  tensor(0.8148)
# Epoch  49 Sharpe:  tensor(0.8351)
# Epoch  50 Sharpe:  tensor(0.8573)
# Epoch  51 Sharpe:  tensor(0.8832)
# Epoch  52 Sharpe:  tensor(0.9113)
# Epoch  53 Sharpe:  tensor(0.9380)
# Epoch  54 Sharpe:  tensor(0.9618)
# Epoch  55 Sharpe:  tensor(0.9819)
# Epoch  56 Sharpe:  tensor(0.9963)
# Epoch  57 Sharpe:  tensor(1.0080)
# Epoch  58 Sharpe:  tensor(1.0196)
# Epoch  59 Sharpe:  tensor(1.0302)
# Epoch  60 Sharpe:  tensor(1.0416)
# Epoch  61 Sharpe:  tensor(1.0560)
# Epoch  62 Sharpe:  tensor(1.0717)
# Epoch  63 Sharpe:  tensor(1.0857)
# Epoch  64 Sharpe:  tensor(1.0989)
# Epoch  65 Sharpe:  tensor(1.1140)
# Epoch  66 Sharpe:  tensor(1.1288)
# Epoch  67 Sharpe:  tensor(1.1441)
# Epoch  68 Sharpe:  tensor(1.1614)
# Epoch  69 Sharpe:  tensor(1.1777)
# Epoch  70 Sharpe:  tensor(1.1930)
# Epoch  71 Sharpe:  tensor(1.2076)
# Epoch  72 Sharpe:  tensor(1.2195)
# Epoch  73 Sharpe:  tensor(1.2312)
# Epoch  74 Sharpe:  tensor(1.2425)
# Epoch  75 Sharpe:  tensor(1.2525)
# Epoch  76 Sharpe:  tensor(1.2618)
# Epoch  77 Sharpe:  tensor(1.2698)
# Epoch  78 Sharpe:  tensor(1.2771)
# Epoch  79 Sharpe:  tensor(1.2846)
# Epoch  80 Sharpe:  tensor(1.2920)
# Epoch  81 Sharpe:  tensor(1.2995)
# Epoch  82 Sharpe:  tensor(1.3072)
# Epoch  83 Sharpe:  tensor(1.3147)
# Epoch  84 Sharpe:  tensor(1.3222)
# Epoch  85 Sharpe:  tensor(1.3293)
# Epoch  86 Sharpe:  tensor(1.3359)
# Epoch  87 Sharpe:  tensor(1.3428)
# Epoch  88 Sharpe:  tensor(1.3502)
# Epoch  89 Sharpe:  tensor(1.3574)
# Epoch  90 Sharpe:  tensor(1.3641)
# Epoch  91 Sharpe:  tensor(1.3701)
# Epoch  92 Sharpe:  tensor(1.3754)
# Epoch  93 Sharpe:  tensor(1.3804)
# Epoch  94 Sharpe:  tensor(1.3852)
# Epoch  95 Sharpe:  tensor(1.3898)
# Epoch  96 Sharpe:  tensor(1.3943)
# Epoch  97 Sharpe:  tensor(1.3987)
# Epoch  98 Sharpe:  tensor(1.4032)
# Epoch  99 Sharpe:  tensor(1.4076)
# Epoch  100 Sharpe:  tensor(1.4118)
# Epoch  101 Sharpe:  tensor(1.4162)
# Epoch  102 Sharpe:  tensor(1.4206)
# Epoch  103 Sharpe:  tensor(1.4248)
# Epoch  104 Sharpe:  tensor(1.4288)
# Epoch  105 Sharpe:  tensor(1.4325)
# Epoch  106 Sharpe:  tensor(1.4360)
# Epoch  107 Sharpe:  tensor(1.4396)
# Epoch  108 Sharpe:  tensor(1.4434)
# Epoch  109 Sharpe:  tensor(1.4470)
# Epoch  110 Sharpe:  tensor(1.4504)
# Epoch  111 Sharpe:  tensor(1.4537)
# Epoch  112 Sharpe:  tensor(1.4570)
# Epoch  113 Sharpe:  tensor(1.4606)
# Epoch  114 Sharpe:  tensor(1.4642)
# Epoch  115 Sharpe:  tensor(1.4677)
# Epoch  116 Sharpe:  tensor(1.4711)
# Epoch  117 Sharpe:  tensor(1.4746)
# Epoch  118 Sharpe:  tensor(1.4784)
# Epoch  119 Sharpe:  tensor(1.4824)
# Epoch  120 Sharpe:  tensor(1.4863)
# Epoch  121 Sharpe:  tensor(1.4902)
# Epoch  122 Sharpe:  tensor(1.4941)
# Epoch  123 Sharpe:  tensor(1.4979)
# Epoch  124 Sharpe:  tensor(1.5019)
# Epoch  125 Sharpe:  tensor(1.5058)
# Epoch  126 Sharpe:  tensor(1.5098)
# Epoch  127 Sharpe:  tensor(1.5139)
# Epoch  128 Sharpe:  tensor(1.5180)
# Epoch  129 Sharpe:  tensor(1.5225)
# Epoch  130 Sharpe:  tensor(1.5273)
# Epoch  131 Sharpe:  tensor(1.5329)
# Epoch  132 Sharpe:  tensor(1.5403)
# Epoch  133 Sharpe:  tensor(1.5515)
# Epoch  134 Sharpe:  tensor(1.5698)
# Epoch  135 Sharpe:  tensor(1.5950)
# Epoch  136 Sharpe:  tensor(1.6197)
# Epoch  137 Sharpe:  tensor(1.6427)
# Epoch  138 Sharpe:  tensor(1.6541)
# Epoch  139 Sharpe:  tensor(1.6587)
# Epoch  140 Sharpe:  tensor(1.6766)
# Epoch  141 Sharpe:  tensor(1.6981)
# Epoch  142 Sharpe:  tensor(1.7094)
# Epoch  143 Sharpe:  tensor(1.7150)
# Epoch  144 Sharpe:  tensor(1.7224)
# Epoch  145 Sharpe:  tensor(1.7353)
# Epoch  146 Sharpe:  tensor(1.7468)
# Epoch  147 Sharpe:  tensor(1.7580)
# Epoch  148 Sharpe:  tensor(1.7636)
# Epoch  149 Sharpe:  tensor(1.7714)
# Epoch  150 Sharpe:  tensor(1.7803)
# Epoch  151 Sharpe:  tensor(1.7905)
# Epoch  152 Sharpe:  tensor(1.7963)
# Epoch  153 Sharpe:  tensor(1.8007)
# Epoch  154 Sharpe:  tensor(1.8099)
# Epoch  155 Sharpe:  tensor(1.8175)
# Epoch  156 Sharpe:  tensor(1.8237)
# Epoch  157 Sharpe:  tensor(1.8286)
# Epoch  158 Sharpe:  tensor(1.8344)
# Epoch  159 Sharpe:  tensor(1.8399)
# Epoch  160 Sharpe:  tensor(1.8460)
# Epoch  161 Sharpe:  tensor(1.8506)
# Epoch  162 Sharpe:  tensor(1.8548)
# Epoch  163 Sharpe:  tensor(1.8592)
# Epoch  164 Sharpe:  tensor(1.8635)
# Epoch  165 Sharpe:  tensor(1.8678)
# Epoch  166 Sharpe:  tensor(1.8728)
# Epoch  167 Sharpe:  tensor(1.8787)
# Epoch  168 Sharpe:  tensor(1.8871)
# Epoch  169 Sharpe:  tensor(1.8978)
# Epoch  170 Sharpe:  tensor(1.9073)
# Epoch  171 Sharpe:  tensor(1.9152)
# Epoch  172 Sharpe:  tensor(1.9258)
# Epoch  173 Sharpe:  tensor(1.9360)
# Epoch  174 Sharpe:  tensor(1.9405)
# Epoch  175 Sharpe:  tensor(1.9458)
# Epoch  176 Sharpe:  tensor(1.9526)
# Epoch  177 Sharpe:  tensor(1.9596)
# Epoch  178 Sharpe:  tensor(1.9650)
# Epoch  179 Sharpe:  tensor(1.9677)
# Epoch  180 Sharpe:  tensor(1.9717)
# Epoch  181 Sharpe:  tensor(1.9757)
# Epoch  182 Sharpe:  tensor(1.9780)
# Epoch  183 Sharpe:  tensor(1.9809)
# Epoch  184 Sharpe:  tensor(1.9836)
# Epoch  185 Sharpe:  tensor(1.9862)
# Epoch  186 Sharpe:  tensor(1.9878)
# Epoch  187 Sharpe:  tensor(1.9893)
# Epoch  188 Sharpe:  tensor(1.9909)
# Epoch  189 Sharpe:  tensor(1.9933)
# Epoch  190 Sharpe:  tensor(1.9962)
# Epoch  191 Sharpe:  tensor(2.0006)
# Epoch  192 Sharpe:  tensor(2.0076)
# Epoch  193 Sharpe:  tensor(2.0238)
# Epoch  194 Sharpe:  tensor(2.0514)
# Epoch  195 Sharpe:  tensor(2.0716)
# Epoch  196 Sharpe:  tensor(2.1002)
# Epoch  197 Sharpe:  tensor(2.1268)
# Epoch  198 Sharpe:  tensor(2.1361)
# Epoch  199 Sharpe:  tensor(2.1544)
# Epoch  200 Sharpe:  tensor(2.1653)
# Epoch  201 Sharpe:  tensor(2.1326)
# Epoch  202 Sharpe:  tensor(2.1824)
# Epoch  203 Sharpe:  tensor(2.1405)
# Epoch  204 Sharpe:  tensor(2.1428)
# Epoch  205 Sharpe:  tensor(2.1488)
# Epoch  206 Sharpe:  tensor(2.2159)
# Epoch  207 Sharpe:  tensor(2.1455)
# Epoch  208 Sharpe:  tensor(2.2088)
# Epoch  209 Sharpe:  tensor(2.1355)
# Epoch  210 Sharpe:  tensor(2.1892)
# Epoch  211 Sharpe:  tensor(2.2338)
# Epoch  212 Sharpe:  tensor(2.1949)
# Epoch  213 Sharpe:  tensor(2.2537)
# Epoch  214 Sharpe:  tensor(2.2408)
# Epoch  215 Sharpe:  tensor(2.2199)
# Epoch  216 Sharpe:  tensor(2.2654)
# Epoch  217 Sharpe:  tensor(2.2602)
# Epoch  218 Sharpe:  tensor(2.2709)
# Epoch  219 Sharpe:  tensor(2.2867)
# Epoch  220 Sharpe:  tensor(2.2781)
# Epoch  221 Sharpe:  tensor(2.2838)
# Epoch  222 Sharpe:  tensor(2.2966)
# Epoch  223 Sharpe:  tensor(2.2905)
# Epoch  224 Sharpe:  tensor(2.2949)
# Epoch  225 Sharpe:  tensor(2.3002)
# Epoch  226 Sharpe:  tensor(2.3049)
# Epoch  227 Sharpe:  tensor(2.3163)
# Epoch  228 Sharpe:  tensor(2.3223)
# Epoch  229 Sharpe:  tensor(2.3257)
# Epoch  230 Sharpe:  tensor(2.3250)
# Epoch  231 Sharpe:  tensor(2.3299)
# Epoch  232 Sharpe:  tensor(2.3370)
# Epoch  233 Sharpe:  tensor(2.3416)
# Epoch  234 Sharpe:  tensor(2.3475)
# Epoch  235 Sharpe:  tensor(2.3514)
# Epoch  236 Sharpe:  tensor(2.3503)
# Epoch  237 Sharpe:  tensor(2.3563)
# Epoch  238 Sharpe:  tensor(2.3593)
# Epoch  239 Sharpe:  tensor(2.3630)
# Epoch  240 Sharpe:  tensor(2.3635)
# Epoch  241 Sharpe:  tensor(2.3647)
# Epoch  242 Sharpe:  tensor(2.3671)
# Epoch  243 Sharpe:  tensor(2.3690)
# Epoch  244 Sharpe:  tensor(2.3721)
# Epoch  245 Sharpe:  tensor(2.3736)
# Epoch  246 Sharpe:  tensor(2.3750)
# Epoch  247 Sharpe:  tensor(2.3768)
# Epoch  248 Sharpe:  tensor(2.3777)
# Epoch  249 Sharpe:  tensor(2.3797)
# Epoch  250 Sharpe:  tensor(2.3808)
# Epoch  251 Sharpe:  tensor(2.3823)
# Epoch  252 Sharpe:  tensor(2.3839)
# Epoch  253 Sharpe:  tensor(2.3849)
# Epoch  254 Sharpe:  tensor(2.3862)
# Epoch  255 Sharpe:  tensor(2.3872)
# Epoch  256 Sharpe:  tensor(2.3878)
# Epoch  257 Sharpe:  tensor(2.3889)
# Epoch  258 Sharpe:  tensor(2.3897)
# Epoch  259 Sharpe:  tensor(2.3904)
# Epoch  260 Sharpe:  tensor(2.3914)
# Epoch  261 Sharpe:  tensor(2.3920)
# Epoch  262 Sharpe:  tensor(2.3926)
# Epoch  263 Sharpe:  tensor(2.3933)
# Epoch  264 Sharpe:  tensor(2.3938)
# Epoch  265 Sharpe:  tensor(2.3943)
# Epoch  266 Sharpe:  tensor(2.3950)
# Epoch  267 Sharpe:  tensor(2.3955)
# Epoch  268 Sharpe:  tensor(2.3959)
# Epoch  269 Sharpe:  tensor(2.3964)
# Epoch  270 Sharpe:  tensor(2.3969)
# Epoch  271 Sharpe:  tensor(2.3973)
# Epoch  272 Sharpe:  tensor(2.3977)
# Epoch  273 Sharpe:  tensor(2.3981)
# Epoch  274 Sharpe:  tensor(2.3984)
# Epoch  275 Sharpe:  tensor(2.3988)
# Epoch  276 Sharpe:  tensor(2.3991)
# Epoch  277 Sharpe:  tensor(2.3994)
# Epoch  278 Sharpe:  tensor(2.3997)
# Epoch  279 Sharpe:  tensor(2.4001)
# Epoch  280 Sharpe:  tensor(2.4004)
# Epoch  281 Sharpe:  tensor(2.4007)
# Epoch  282 Sharpe:  tensor(2.4010)
# Epoch  283 Sharpe:  tensor(2.4014)
# Epoch  284 Sharpe:  tensor(2.4018)
# Epoch  285 Sharpe:  tensor(2.4023)
# Epoch  286 Sharpe:  tensor(2.4030)
# Epoch  287 Sharpe:  tensor(2.4039)
# Epoch  288 Sharpe:  tensor(2.4052)
# Epoch  289 Sharpe:  tensor(2.4068)
# Epoch  290 Sharpe:  tensor(2.4086)
# Epoch  291 Sharpe:  tensor(2.4103)
# Epoch  292 Sharpe:  tensor(2.4117)
# Epoch  293 Sharpe:  tensor(2.4130)
# Epoch  294 Sharpe:  tensor(2.4141)
# Epoch  295 Sharpe:  tensor(2.4148)
# Epoch  296 Sharpe:  tensor(2.4154)
# Epoch  297 Sharpe:  tensor(2.4159)
# Epoch  298 Sharpe:  tensor(2.4163)
# Epoch  299 Sharpe:  tensor(2.4166)
# Epoch  300 Sharpe:  tensor(2.4169)
# Epoch  301 Sharpe:  tensor(2.4172)
# Epoch  302 Sharpe:  tensor(2.4174)
# Epoch  303 Sharpe:  tensor(2.4176)
# Epoch  304 Sharpe:  tensor(2.4178)
# Epoch  305 Sharpe:  tensor(2.4180)
# Epoch  306 Sharpe:  tensor(2.4182)
# Epoch  307 Sharpe:  tensor(2.4183)
# Epoch  308 Sharpe:  tensor(2.4184)
# Epoch  309 Sharpe:  tensor(2.4186)
# Epoch  310 Sharpe:  tensor(2.4187)
# Epoch  311 Sharpe:  tensor(2.4188)
# Epoch  312 Sharpe:  tensor(2.4189)
# Epoch  313 Sharpe:  tensor(2.4191)
# Epoch  314 Sharpe:  tensor(2.4192)
# Epoch  315 Sharpe:  tensor(2.4192)
# Epoch  316 Sharpe:  tensor(2.4193)
# Epoch  317 Sharpe:  tensor(2.4194)
# Epoch  318 Sharpe:  tensor(2.4195)
# Epoch  319 Sharpe:  tensor(2.4196)
# Epoch  320 Sharpe:  tensor(2.4197)
# Epoch  321 Sharpe:  tensor(2.4197)
# Epoch  322 Sharpe:  tensor(2.4198)
# Epoch  323 Sharpe:  tensor(2.4199)
# Epoch  324 Sharpe:  tensor(2.4200)
# Epoch  325 Sharpe:  tensor(2.4200)
# Epoch  326 Sharpe:  tensor(2.4201)
# Epoch  327 Sharpe:  tensor(2.4202)
# Epoch  328 Sharpe:  tensor(2.4202)
# Epoch  329 Sharpe:  tensor(2.4203)
# Epoch  330 Sharpe:  tensor(2.4204)
# Epoch  331 Sharpe:  tensor(2.4204)
# Epoch  332 Sharpe:  tensor(2.4205)
# Epoch  333 Sharpe:  tensor(2.4205)
# Epoch  334 Sharpe:  tensor(2.4206)
# Epoch  335 Sharpe:  tensor(2.4206)
# Epoch  336 Sharpe:  tensor(2.4207)
# Epoch  337 Sharpe:  tensor(2.4208)
# Epoch  338 Sharpe:  tensor(2.4208)
# Epoch  339 Sharpe:  tensor(2.4209)
# Epoch  340 Sharpe:  tensor(2.4209)
# Epoch  341 Sharpe:  tensor(2.4210)
# Epoch  342 Sharpe:  tensor(2.4210)
# Epoch  343 Sharpe:  tensor(2.4210)
# Epoch  344 Sharpe:  tensor(2.4211)
# Epoch  345 Sharpe:  tensor(2.4211)
# Epoch  346 Sharpe:  tensor(2.4212)
# Epoch  347 Sharpe:  tensor(2.4212)
# Epoch  348 Sharpe:  tensor(2.4213)
# Epoch  349 Sharpe:  tensor(2.4213)
# Epoch  350 Sharpe:  tensor(2.4214)
# Epoch  351 Sharpe:  tensor(2.4214)
# Epoch  352 Sharpe:  tensor(2.4214)
# Epoch  353 Sharpe:  tensor(2.4215)
# Epoch  354 Sharpe:  tensor(2.4215)
# Epoch  355 Sharpe:  tensor(2.4216)
# Epoch  356 Sharpe:  tensor(2.4216)
# Epoch  357 Sharpe:  tensor(2.4216)
# Epoch  358 Sharpe:  tensor(2.4217)
# Epoch  359 Sharpe:  tensor(2.4217)
# Epoch  360 Sharpe:  tensor(2.4218)
# Epoch  361 Sharpe:  tensor(2.4218)
# Epoch  362 Sharpe:  tensor(2.4218)
# Epoch  363 Sharpe:  tensor(2.4219)
# Epoch  364 Sharpe:  tensor(2.4219)
# Epoch  365 Sharpe:  tensor(2.4220)
# Epoch  366 Sharpe:  tensor(2.4220)
# Epoch  367 Sharpe:  tensor(2.4220)
# Epoch  368 Sharpe:  tensor(2.4221)
# Epoch  369 Sharpe:  tensor(2.4221)
# Epoch  370 Sharpe:  tensor(2.4222)
# Epoch  371 Sharpe:  tensor(2.4222)
# Epoch  372 Sharpe:  tensor(2.4222)
# Epoch  373 Sharpe:  tensor(2.4223)
# Epoch  374 Sharpe:  tensor(2.4223)
# Epoch  375 Sharpe:  tensor(2.4224)
# Epoch  376 Sharpe:  tensor(2.4224)
# Epoch  377 Sharpe:  tensor(2.4225)
# Epoch  378 Sharpe:  tensor(2.4225)
# Epoch  379 Sharpe:  tensor(2.4225)
# Epoch  380 Sharpe:  tensor(2.4226)
# Epoch  381 Sharpe:  tensor(2.4226)
# Epoch  382 Sharpe:  tensor(2.4226)
# Epoch  383 Sharpe:  tensor(2.4227)
# Epoch  384 Sharpe:  tensor(2.4227)
# Epoch  385 Sharpe:  tensor(2.4228)
# Epoch  386 Sharpe:  tensor(2.4228)
# Epoch  387 Sharpe:  tensor(2.4228)
# Epoch  388 Sharpe:  tensor(2.4229)
# Epoch  389 Sharpe:  tensor(2.4229)
# Epoch  390 Sharpe:  tensor(2.4229)
# Epoch  391 Sharpe:  tensor(2.4230)
# Epoch  392 Sharpe:  tensor(2.4230)
# Epoch  393 Sharpe:  tensor(2.4231)
# Epoch  394 Sharpe:  tensor(2.4231)
# Epoch  395 Sharpe:  tensor(2.4231)
# Epoch  396 Sharpe:  tensor(2.4232)
# Epoch  397 Sharpe:  tensor(2.4232)
# Epoch  398 Sharpe:  tensor(2.4233)
# Epoch  399 Sharpe:  tensor(2.4233)
# Epoch  400 Sharpe:  tensor(2.4234)
# Epoch  401 Sharpe:  tensor(2.4235)
# Epoch  402 Sharpe:  tensor(2.4236)
# Epoch  403 Sharpe:  tensor(2.4237)
# Epoch  404 Sharpe:  tensor(2.4238)
# Epoch  405 Sharpe:  tensor(2.4239)
# Epoch  406 Sharpe:  tensor(2.4241)
# Epoch  407 Sharpe:  tensor(2.4243)
# Epoch  408 Sharpe:  tensor(2.4245)
# Epoch  409 Sharpe:  tensor(2.4247)
# Epoch  410 Sharpe:  tensor(2.4249)
# Epoch  411 Sharpe:  tensor(2.4251)
# Epoch  412 Sharpe:  tensor(2.4253)
# Epoch  413 Sharpe:  tensor(2.4256)
# Epoch  414 Sharpe:  tensor(2.4258)
# Epoch  415 Sharpe:  tensor(2.4260)
# Epoch  416 Sharpe:  tensor(2.4262)
# Epoch  417 Sharpe:  tensor(2.4264)
# Epoch  418 Sharpe:  tensor(2.4267)
# Epoch  419 Sharpe:  tensor(2.4269)
# Epoch  420 Sharpe:  tensor(2.4271)
# Epoch  421 Sharpe:  tensor(2.4274)
# Epoch  422 Sharpe:  tensor(2.4277)
# Epoch  423 Sharpe:  tensor(2.4280)
# Epoch  424 Sharpe:  tensor(2.4284)
# Epoch  425 Sharpe:  tensor(2.4288)
# Epoch  426 Sharpe:  tensor(2.4294)
# Epoch  427 Sharpe:  tensor(2.4303)
# Epoch  428 Sharpe:  tensor(2.4315)
# Epoch  429 Sharpe:  tensor(2.4334)
# Epoch  430 Sharpe:  tensor(2.4356)
# Epoch  431 Sharpe:  tensor(2.4373)
# Epoch  432 Sharpe:  tensor(2.4384)
# Epoch  433 Sharpe:  tensor(2.4391)
# Epoch  434 Sharpe:  tensor(2.4399)
# Epoch  435 Sharpe:  tensor(2.4407)
# Epoch  436 Sharpe:  tensor(2.4415)
# Epoch  437 Sharpe:  tensor(2.4419)
# Epoch  438 Sharpe:  tensor(2.4422)
# Epoch  439 Sharpe:  tensor(2.4424)
# Epoch  440 Sharpe:  tensor(2.4427)
# Epoch  441 Sharpe:  tensor(2.4429)
# Epoch  442 Sharpe:  tensor(2.4432)
# Epoch  443 Sharpe:  tensor(2.4434)
# Epoch  444 Sharpe:  tensor(2.4436)
# Epoch  445 Sharpe:  tensor(2.4437)
# Epoch  446 Sharpe:  tensor(2.4438)
# Epoch  447 Sharpe:  tensor(2.4439)
# Epoch  448 Sharpe:  tensor(2.4440)
# Epoch  449 Sharpe:  tensor(2.4442)
# Epoch  450 Sharpe:  tensor(2.4443)
# Epoch  451 Sharpe:  tensor(2.4444)
# Epoch  452 Sharpe:  tensor(2.4444)
# Epoch  453 Sharpe:  tensor(2.4445)
# Epoch  454 Sharpe:  tensor(2.4446)
# Epoch  455 Sharpe:  tensor(2.4446)
# Epoch  456 Sharpe:  tensor(2.4447)
# Epoch  457 Sharpe:  tensor(2.4448)
# Epoch  458 Sharpe:  tensor(2.4448)
# Epoch  459 Sharpe:  tensor(2.4449)
# Epoch  460 Sharpe:  tensor(2.4450)
# Epoch  461 Sharpe:  tensor(2.4450)
# Epoch  462 Sharpe:  tensor(2.4451)
# Epoch  463 Sharpe:  tensor(2.4451)
# Epoch  464 Sharpe:  tensor(2.4451)
# Epoch  465 Sharpe:  tensor(2.4452)
# Epoch  466 Sharpe:  tensor(2.4452)
# Epoch  467 Sharpe:  tensor(2.4453)
# Epoch  468 Sharpe:  tensor(2.4453)
# Epoch  469 Sharpe:  tensor(2.4454)
# Epoch  470 Sharpe:  tensor(2.4454)
# Epoch  471 Sharpe:  tensor(2.4455)
# Epoch  472 Sharpe:  tensor(2.4455)
# Epoch  473 Sharpe:  tensor(2.4455)
# Epoch  474 Sharpe:  tensor(2.4456)
# Epoch  475 Sharpe:  tensor(2.4456)
# Epoch  476 Sharpe:  tensor(2.4456)
# Epoch  477 Sharpe:  tensor(2.4457)
# Epoch  478 Sharpe:  tensor(2.4457)
# Epoch  479 Sharpe:  tensor(2.4457)
# Epoch  480 Sharpe:  tensor(2.4457)
# Epoch  481 Sharpe:  tensor(2.4458)
# Epoch  482 Sharpe:  tensor(2.4458)
# Epoch  483 Sharpe:  tensor(2.4458)
# Epoch  484 Sharpe:  tensor(2.4459)
# Epoch  485 Sharpe:  tensor(2.4459)
# Epoch  486 Sharpe:  tensor(2.4459)
# Epoch  487 Sharpe:  tensor(2.4459)
# Epoch  488 Sharpe:  tensor(2.4459)
# Epoch  489 Sharpe:  tensor(2.4460)
# Epoch  490 Sharpe:  tensor(2.4460)
# Epoch  491 Sharpe:  tensor(2.4460)
# Epoch  492 Sharpe:  tensor(2.4460)
# Epoch  493 Sharpe:  tensor(2.4460)
# Epoch  494 Sharpe:  tensor(2.4461)
# Epoch  495 Sharpe:  tensor(2.4461)
# Epoch  496 Sharpe:  tensor(2.4461)
# Epoch  497 Sharpe:  tensor(2.4461)
# Epoch  498 Sharpe:  tensor(2.4461)
# Epoch  499 Sharpe:  tensor(2.4462)
# Epoch  500 Sharpe:  tensor(2.4462)
# Epoch  501 Sharpe:  tensor(2.4462)
# Epoch  502 Sharpe:  tensor(2.4462)
# Epoch  503 Sharpe:  tensor(2.4462)
# Epoch  504 Sharpe:  tensor(2.4462)
# Epoch  505 Sharpe:  tensor(2.4463)
# Epoch  506 Sharpe:  tensor(2.4463)
# Epoch  507 Sharpe:  tensor(2.4463)
# Epoch  508 Sharpe:  tensor(2.4463)
# Epoch  509 Sharpe:  tensor(2.4463)
# Epoch  510 Sharpe:  tensor(2.4463)
# Epoch  511 Sharpe:  tensor(2.4463)
# Epoch  512 Sharpe:  tensor(2.4464)
# Epoch  513 Sharpe:  tensor(2.4464)
# Epoch  514 Sharpe:  tensor(2.4464)
# Epoch  515 Sharpe:  tensor(2.4464)
# Epoch  516 Sharpe:  tensor(2.4464)
# Epoch  517 Sharpe:  tensor(2.4464)
# Epoch  518 Sharpe:  tensor(2.4464)
# Epoch  519 Sharpe:  tensor(2.4464)
# Epoch  520 Sharpe:  tensor(2.4465)
# Epoch  521 Sharpe:  tensor(2.4465)
# Epoch  522 Sharpe:  tensor(2.4465)
# Epoch  523 Sharpe:  tensor(2.4465)
# Epoch  524 Sharpe:  tensor(2.4465)
# Epoch  525 Sharpe:  tensor(2.4465)
# Epoch  526 Sharpe:  tensor(2.4465)
# Epoch  527 Sharpe:  tensor(2.4465)
# Epoch  528 Sharpe:  tensor(2.4465)
# Epoch  529 Sharpe:  tensor(2.4466)
# Epoch  530 Sharpe:  tensor(2.4466)
# Epoch  531 Sharpe:  tensor(2.4466)
# Epoch  532 Sharpe:  tensor(2.4466)
# Epoch  533 Sharpe:  tensor(2.4466)
# Epoch  534 Sharpe:  tensor(2.4466)
# Epoch  535 Sharpe:  tensor(2.4466)
# Epoch  536 Sharpe:  tensor(2.4466)
# Epoch  537 Sharpe:  tensor(2.4466)
# Epoch  538 Sharpe:  tensor(2.4466)
# Epoch  539 Sharpe:  tensor(2.4467)
# Epoch  540 Sharpe:  tensor(2.4467)
# Epoch  541 Sharpe:  tensor(2.4467)
# Epoch  542 Sharpe:  tensor(2.4467)
# Epoch  543 Sharpe:  tensor(2.4467)
# Epoch  544 Sharpe:  tensor(2.4467)
# Epoch  545 Sharpe:  tensor(2.4467)
# Epoch  546 Sharpe:  tensor(2.4467)
# Epoch  547 Sharpe:  tensor(2.4467)
# Epoch  548 Sharpe:  tensor(2.4467)
# Epoch  549 Sharpe:  tensor(2.4467)
# Epoch  550 Sharpe:  tensor(2.4467)
# Epoch  551 Sharpe:  tensor(2.4468)
# Epoch  552 Sharpe:  tensor(2.4468)
# Epoch  553 Sharpe:  tensor(2.4468)
# Epoch  554 Sharpe:  tensor(2.4468)
# Epoch  555 Sharpe:  tensor(2.4468)
# Epoch  556 Sharpe:  tensor(2.4468)
# Epoch  557 Sharpe:  tensor(2.4468)
# Epoch  558 Sharpe:  tensor(2.4468)
# Epoch  559 Sharpe:  tensor(2.4468)
# Epoch  560 Sharpe:  tensor(2.4468)
# Epoch  561 Sharpe:  tensor(2.4468)
# Epoch  562 Sharpe:  tensor(2.4468)
# Epoch  563 Sharpe:  tensor(2.4468)
# Epoch  564 Sharpe:  tensor(2.4469)
# Epoch  565 Sharpe:  tensor(2.4469)
# Epoch  566 Sharpe:  tensor(2.4469)
# Epoch  567 Sharpe:  tensor(2.4469)
# Epoch  568 Sharpe:  tensor(2.4469)
# Epoch  569 Sharpe:  tensor(2.4469)
# Epoch  570 Sharpe:  tensor(2.4469)
# Epoch  571 Sharpe:  tensor(2.4469)
# Epoch  572 Sharpe:  tensor(2.4469)
# Epoch  573 Sharpe:  tensor(2.4469)
# Epoch  574 Sharpe:  tensor(2.4469)
# Epoch  575 Sharpe:  tensor(2.4469)
# Epoch  576 Sharpe:  tensor(2.4469)
# Epoch  577 Sharpe:  tensor(2.4469)
# Epoch  578 Sharpe:  tensor(2.4469)
# Epoch  579 Sharpe:  tensor(2.4469)
# Epoch  580 Sharpe:  tensor(2.4470)
# Epoch  581 Sharpe:  tensor(2.4470)
# Epoch  582 Sharpe:  tensor(2.4470)
# Epoch  583 Sharpe:  tensor(2.4470)
# Epoch  584 Sharpe:  tensor(2.4470)
# Epoch  585 Sharpe:  tensor(2.4470)
# Epoch  586 Sharpe:  tensor(2.4470)
# Epoch  587 Sharpe:  tensor(2.4470)
# Epoch  588 Sharpe:  tensor(2.4470)
# Epoch  589 Sharpe:  tensor(2.4470)
# Epoch  590 Sharpe:  tensor(2.4470)
# Epoch  591 Sharpe:  tensor(2.4470)
# Epoch  592 Sharpe:  tensor(2.4470)
# Epoch  593 Sharpe:  tensor(2.4470)
# Epoch  594 Sharpe:  tensor(2.4470)
# Epoch  595 Sharpe:  tensor(2.4470)
# Epoch  596 Sharpe:  tensor(2.4470)
# Epoch  597 Sharpe:  tensor(2.4470)
# Epoch  598 Sharpe:  tensor(2.4470)
# Epoch  599 Sharpe:  tensor(2.4471)
# Epoch  600 Sharpe:  tensor(2.4471)
# Epoch  601 Sharpe:  tensor(2.4471)
# Epoch  602 Sharpe:  tensor(2.4471)
# Epoch  603 Sharpe:  tensor(2.4471)
# Epoch  604 Sharpe:  tensor(2.4471)
# Epoch  605 Sharpe:  tensor(2.4471)
# Epoch  606 Sharpe:  tensor(2.4471)
# Epoch  607 Sharpe:  tensor(2.4471)
# Epoch  608 Sharpe:  tensor(2.4471)
# Epoch  609 Sharpe:  tensor(2.4471)
# Epoch  610 Sharpe:  tensor(2.4471)
# Epoch  611 Sharpe:  tensor(2.4471)
# Epoch  612 Sharpe:  tensor(2.4471)
# Epoch  613 Sharpe:  tensor(2.4471)
# Epoch  614 Sharpe:  tensor(2.4471)
# Epoch  615 Sharpe:  tensor(2.4471)
# Epoch  616 Sharpe:  tensor(2.4471)
# Epoch  617 Sharpe:  tensor(2.4471)
# Epoch  618 Sharpe:  tensor(2.4471)
# Epoch  619 Sharpe:  tensor(2.4471)
# Epoch  620 Sharpe:  tensor(2.4471)
# Epoch  621 Sharpe:  tensor(2.4471)
# Epoch  622 Sharpe:  tensor(2.4472)
# Epoch  623 Sharpe:  tensor(2.4472)
# Epoch  624 Sharpe:  tensor(2.4472)
# Epoch  625 Sharpe:  tensor(2.4472)
# Epoch  626 Sharpe:  tensor(2.4472)
# Epoch  627 Sharpe:  tensor(2.4472)
# Epoch  628 Sharpe:  tensor(2.4472)
# Epoch  629 Sharpe:  tensor(2.4472)
# Epoch  630 Sharpe:  tensor(2.4472)
# Epoch  631 Sharpe:  tensor(2.4472)
# Epoch  632 Sharpe:  tensor(2.4472)
# Epoch  633 Sharpe:  tensor(2.4472)
# Epoch  634 Sharpe:  tensor(2.4472)
# Epoch  635 Sharpe:  tensor(2.4472)
# Epoch  636 Sharpe:  tensor(2.4472)
# Epoch  637 Sharpe:  tensor(2.4472)
# Epoch  638 Sharpe:  tensor(2.4472)
# Epoch  639 Sharpe:  tensor(2.4472)
# Epoch  640 Sharpe:  tensor(2.4472)
# Epoch  641 Sharpe:  tensor(2.4472)
# Epoch  642 Sharpe:  tensor(2.4472)
# Epoch  643 Sharpe:  tensor(2.4472)
# Epoch  644 Sharpe:  tensor(2.4472)
# Epoch  645 Sharpe:  tensor(2.4472)
# Epoch  646 Sharpe:  tensor(2.4472)
# Epoch  647 Sharpe:  tensor(2.4472)
# Epoch  648 Sharpe:  tensor(2.4472)
# Epoch  649 Sharpe:  tensor(2.4472)
# Epoch  650 Sharpe:  tensor(2.4473)
# Epoch  651 Sharpe:  tensor(2.4473)
# Epoch  652 Sharpe:  tensor(2.4473)
# Epoch  653 Sharpe:  tensor(2.4473)
# Epoch  654 Sharpe:  tensor(2.4473)
# Epoch  655 Sharpe:  tensor(2.4473)
# Epoch  656 Sharpe:  tensor(2.4473)
# Epoch  657 Sharpe:  tensor(2.4473)
# Epoch  658 Sharpe:  tensor(2.4473)
# Epoch  659 Sharpe:  tensor(2.4473)
# Epoch  660 Sharpe:  tensor(2.4473)
# Epoch  661 Sharpe:  tensor(2.4473)
# Epoch  662 Sharpe:  tensor(2.4473)
# Epoch  663 Sharpe:  tensor(2.4473)
# Epoch  664 Sharpe:  tensor(2.4473)
# Epoch  665 Sharpe:  tensor(2.4473)
# Epoch  666 Sharpe:  tensor(2.4473)
# Epoch  667 Sharpe:  tensor(2.4473)
# Epoch  668 Sharpe:  tensor(2.4473)
# Epoch  669 Sharpe:  tensor(2.4473)
# Epoch  670 Sharpe:  tensor(2.4473)
# Epoch  671 Sharpe:  tensor(2.4473)
# Epoch  672 Sharpe:  tensor(2.4473)
# Epoch  673 Sharpe:  tensor(2.4473)
# Epoch  674 Sharpe:  tensor(2.4473)
# Epoch  675 Sharpe:  tensor(2.4473)
# Epoch  676 Sharpe:  tensor(2.4473)
# Epoch  677 Sharpe:  tensor(2.4473)
# Epoch  678 Sharpe:  tensor(2.4473)
# Epoch  679 Sharpe:  tensor(2.4473)
# Epoch  680 Sharpe:  tensor(2.4473)
# Epoch  681 Sharpe:  tensor(2.4473)
# Epoch  682 Sharpe:  tensor(2.4473)
# Epoch  683 Sharpe:  tensor(2.4473)
# Epoch  684 Sharpe:  tensor(2.4473)
# Epoch  685 Sharpe:  tensor(2.4474)
# Epoch  686 Sharpe:  tensor(2.4474)
# Epoch  687 Sharpe:  tensor(2.4474)
# Epoch  688 Sharpe:  tensor(2.4474)
# Epoch  689 Sharpe:  tensor(2.4474)
# Epoch  690 Sharpe:  tensor(2.4474)
# Epoch  691 Sharpe:  tensor(2.4474)
# Epoch  692 Sharpe:  tensor(2.4474)
# Epoch  693 Sharpe:  tensor(2.4474)
# Epoch  694 Sharpe:  tensor(2.4474)
# Epoch  695 Sharpe:  tensor(2.4474)
# Epoch  696 Sharpe:  tensor(2.4474)
# Epoch  697 Sharpe:  tensor(2.4474)
# Epoch  698 Sharpe:  tensor(2.4474)
# Epoch  699 Sharpe:  tensor(2.4474)
# Epoch  700 Sharpe:  tensor(2.4474)
# Epoch  701 Sharpe:  tensor(2.4474)
# Epoch  702 Sharpe:  tensor(2.4474)
# Epoch  703 Sharpe:  tensor(2.4474)
# Epoch  704 Sharpe:  tensor(2.4474)
# Epoch  705 Sharpe:  tensor(2.4474)
# Epoch  706 Sharpe:  tensor(2.4474)
# Epoch  707 Sharpe:  tensor(2.4474)
# Epoch  708 Sharpe:  tensor(2.4474)
# Epoch  709 Sharpe:  tensor(2.4474)
# Epoch  710 Sharpe:  tensor(2.4474)
# Epoch  711 Sharpe:  tensor(2.4474)
# Epoch  712 Sharpe:  tensor(2.4474)
# Epoch  713 Sharpe:  tensor(2.4474)
# Epoch  714 Sharpe:  tensor(2.4474)
# Epoch  715 Sharpe:  tensor(2.4474)
# Epoch  716 Sharpe:  tensor(2.4474)
# Epoch  717 Sharpe:  tensor(2.4474)
# Epoch  718 Sharpe:  tensor(2.4474)
# Epoch  719 Sharpe:  tensor(2.4474)
# Epoch  720 Sharpe:  tensor(2.4474)
# Epoch  721 Sharpe:  tensor(2.4474)
# Epoch  722 Sharpe:  tensor(2.4474)
# Epoch  723 Sharpe:  tensor(2.4474)
# Epoch  724 Sharpe:  tensor(2.4474)
# Epoch  725 Sharpe:  tensor(2.4474)
# Epoch  726 Sharpe:  tensor(2.4474)
# Epoch  727 Sharpe:  tensor(2.4474)
# Epoch  728 Sharpe:  tensor(2.4474)
# Epoch  729 Sharpe:  tensor(2.4474)
# Epoch  730 Sharpe:  tensor(2.4475)
# Epoch  731 Sharpe:  tensor(2.4475)
# Epoch  732 Sharpe:  tensor(2.4475)
# Epoch  733 Sharpe:  tensor(2.4475)
# Epoch  734 Sharpe:  tensor(2.4475)
# Epoch  735 Sharpe:  tensor(2.4475)
# Epoch  736 Sharpe:  tensor(2.4475)
# Epoch  737 Sharpe:  tensor(2.4475)
# Epoch  738 Sharpe:  tensor(2.4475)
# Epoch  739 Sharpe:  tensor(2.4475)
# Epoch  740 Sharpe:  tensor(2.4475)
# Epoch  741 Sharpe:  tensor(2.4475)
# Epoch  742 Sharpe:  tensor(2.4475)
# Epoch  743 Sharpe:  tensor(2.4475)
# Epoch  744 Sharpe:  tensor(2.4475)
# Epoch  745 Sharpe:  tensor(2.4475)
# Epoch  746 Sharpe:  tensor(2.4475)
# Epoch  747 Sharpe:  tensor(2.4475)
# Epoch  748 Sharpe:  tensor(2.4475)
# Epoch  749 Sharpe:  tensor(2.4475)
# Epoch  750 Sharpe:  tensor(2.4475)
# Epoch  751 Sharpe:  tensor(2.4475)
# Epoch  752 Sharpe:  tensor(2.4475)
# Epoch  753 Sharpe:  tensor(2.4475)
# Epoch  754 Sharpe:  tensor(2.4475)
# Epoch  755 Sharpe:  tensor(2.4475)
# Epoch  756 Sharpe:  tensor(2.4475)
# Epoch  757 Sharpe:  tensor(2.4475)
# Epoch  758 Sharpe:  tensor(2.4475)
# Epoch  759 Sharpe:  tensor(2.4475)
# Epoch  760 Sharpe:  tensor(2.4475)
# Epoch  761 Sharpe:  tensor(2.4475)
# Epoch  762 Sharpe:  tensor(2.4475)
# Epoch  763 Sharpe:  tensor(2.4475)
# Epoch  764 Sharpe:  tensor(2.4475)
# Epoch  765 Sharpe:  tensor(2.4475)
# Epoch  766 Sharpe:  tensor(2.4475)
# Epoch  767 Sharpe:  tensor(2.4475)
# Epoch  768 Sharpe:  tensor(2.4475)
# Epoch  769 Sharpe:  tensor(2.4475)
# Epoch  770 Sharpe:  tensor(2.4475)
# Epoch  771 Sharpe:  tensor(2.4475)
# Epoch  772 Sharpe:  tensor(2.4475)
# Epoch  773 Sharpe:  tensor(2.4475)
# Epoch  774 Sharpe:  tensor(2.4475)
# Epoch  775 Sharpe:  tensor(2.4475)
# Epoch  776 Sharpe:  tensor(2.4475)
# Epoch  777 Sharpe:  tensor(2.4475)
# Epoch  778 Sharpe:  tensor(2.4475)
# Epoch  779 Sharpe:  tensor(2.4475)
# Epoch  780 Sharpe:  tensor(2.4475)
# Epoch  781 Sharpe:  tensor(2.4475)
# Epoch  782 Sharpe:  tensor(2.4475)
# Epoch  783 Sharpe:  tensor(2.4475)
# Epoch  784 Sharpe:  tensor(2.4475)
# Epoch  785 Sharpe:  tensor(2.4475)
# Epoch  786 Sharpe:  tensor(2.4475)
# Epoch  787 Sharpe:  tensor(2.4475)
# Epoch  788 Sharpe:  tensor(2.4475)
# Epoch  789 Sharpe:  tensor(2.4475)
# Epoch  790 Sharpe:  tensor(2.4475)
# Epoch  791 Sharpe:  tensor(2.4476)
# Epoch  792 Sharpe:  tensor(2.4476)
# Epoch  793 Sharpe:  tensor(2.4476)
# Epoch  794 Sharpe:  tensor(2.4476)
# Epoch  795 Sharpe:  tensor(2.4476)
# Epoch  796 Sharpe:  tensor(2.4476)
# Epoch  797 Sharpe:  tensor(2.4476)
# Epoch  798 Sharpe:  tensor(2.4476)
# Epoch  799 Sharpe:  tensor(2.4476)
# Epoch  800 Sharpe:  tensor(2.4476)
# Epoch  801 Sharpe:  tensor(2.4476)
# Epoch  802 Sharpe:  tensor(2.4476)
# Epoch  803 Sharpe:  tensor(2.4476)
# Epoch  804 Sharpe:  tensor(2.4476)
# Epoch  805 Sharpe:  tensor(2.4476)
# Epoch  806 Sharpe:  tensor(2.4476)
# Epoch  807 Sharpe:  tensor(2.4476)
# Epoch  808 Sharpe:  tensor(2.4476)
# Epoch  809 Sharpe:  tensor(2.4476)
# Epoch  810 Sharpe:  tensor(2.4476)
# Epoch  811 Sharpe:  tensor(2.4476)
# Epoch  812 Sharpe:  tensor(2.4476)
# Epoch  813 Sharpe:  tensor(2.4476)
# Epoch  814 Sharpe:  tensor(2.4476)
# Epoch  815 Sharpe:  tensor(2.4476)
# Epoch  816 Sharpe:  tensor(2.4476)
# Epoch  817 Sharpe:  tensor(2.4476)
# Epoch  818 Sharpe:  tensor(2.4476)
# Epoch  819 Sharpe:  tensor(2.4476)
# Epoch  820 Sharpe:  tensor(2.4476)
# Epoch  821 Sharpe:  tensor(2.4476)
# Epoch  822 Sharpe:  tensor(2.4476)
# Epoch  823 Sharpe:  tensor(2.4476)
# Epoch  824 Sharpe:  tensor(2.4476)
# Epoch  825 Sharpe:  tensor(2.4476)
# Epoch  826 Sharpe:  tensor(2.4476)
# Epoch  827 Sharpe:  tensor(2.4476)
# Epoch  828 Sharpe:  tensor(2.4476)
# Epoch  829 Sharpe:  tensor(2.4476)
# Epoch  830 Sharpe:  tensor(2.4476)
# Epoch  831 Sharpe:  tensor(2.4476)
# Epoch  832 Sharpe:  tensor(2.4476)
# Epoch  833 Sharpe:  tensor(2.4476)
# Epoch  834 Sharpe:  tensor(2.4476)
# Epoch  835 Sharpe:  tensor(2.4476)
# Epoch  836 Sharpe:  tensor(2.4476)
# Epoch  837 Sharpe:  tensor(2.4476)
# Epoch  838 Sharpe:  tensor(2.4476)
# Epoch  839 Sharpe:  tensor(2.4476)
# Epoch  840 Sharpe:  tensor(2.4476)
# Epoch  841 Sharpe:  tensor(2.4476)
# Epoch  842 Sharpe:  tensor(2.4476)
# Epoch  843 Sharpe:  tensor(2.4476)
# Epoch  844 Sharpe:  tensor(2.4476)
# Epoch  845 Sharpe:  tensor(2.4476)
# Epoch  846 Sharpe:  tensor(2.4476)
# Epoch  847 Sharpe:  tensor(2.4476)
# Epoch  848 Sharpe:  tensor(2.4476)
# Epoch  849 Sharpe:  tensor(2.4476)
# Epoch  850 Sharpe:  tensor(2.4476)
# Epoch  851 Sharpe:  tensor(2.4476)
# Epoch  852 Sharpe:  tensor(2.4476)
# Epoch  853 Sharpe:  tensor(2.4476)
# Epoch  854 Sharpe:  tensor(2.4476)
# Epoch  855 Sharpe:  tensor(2.4476)
# Epoch  856 Sharpe:  tensor(2.4476)
# Epoch  857 Sharpe:  tensor(2.4476)
# Epoch  858 Sharpe:  tensor(2.4476)
# Epoch  859 Sharpe:  tensor(2.4476)
# Epoch  860 Sharpe:  tensor(2.4476)
# Epoch  861 Sharpe:  tensor(2.4476)
# Epoch  862 Sharpe:  tensor(2.4476)
# Epoch  863 Sharpe:  tensor(2.4476)
# Epoch  864 Sharpe:  tensor(2.4476)
# Epoch  865 Sharpe:  tensor(2.4476)
# Epoch  866 Sharpe:  tensor(2.4476)
# Epoch  867 Sharpe:  tensor(2.4476)
# Epoch  868 Sharpe:  tensor(2.4476)
# Epoch  869 Sharpe:  tensor(2.4476)
# Epoch  870 Sharpe:  tensor(2.4476)
# Epoch  871 Sharpe:  tensor(2.4476)
# Epoch  872 Sharpe:  tensor(2.4476)
# Epoch  873 Sharpe:  tensor(2.4476)
# Epoch  874 Sharpe:  tensor(2.4476)
# Epoch  875 Sharpe:  tensor(2.4476)
# Epoch  876 Sharpe:  tensor(2.4476)
# Epoch  877 Sharpe:  tensor(2.4476)
# Epoch  878 Sharpe:  tensor(2.4477)
# Epoch  879 Sharpe:  tensor(2.4477)
# Epoch  880 Sharpe:  tensor(2.4477)
# Epoch  881 Sharpe:  tensor(2.4477)
# Epoch  882 Sharpe:  tensor(2.4477)
# Epoch  883 Sharpe:  tensor(2.4477)
# Epoch  884 Sharpe:  tensor(2.4477)
# Epoch  885 Sharpe:  tensor(2.4477)
# Epoch  886 Sharpe:  tensor(2.4477)
# Epoch  887 Sharpe:  tensor(2.4477)
# Epoch  888 Sharpe:  tensor(2.4477)
# Epoch  889 Sharpe:  tensor(2.4477)
# Epoch  890 Sharpe:  tensor(2.4477)
# Epoch  891 Sharpe:  tensor(2.4477)
# Epoch  892 Sharpe:  tensor(2.4477)
# Epoch  893 Sharpe:  tensor(2.4477)
# Epoch  894 Sharpe:  tensor(2.4477)
# Epoch  895 Sharpe:  tensor(2.4477)
# Epoch  896 Sharpe:  tensor(2.4477)
# Epoch  897 Sharpe:  tensor(2.4477)
# Epoch  898 Sharpe:  tensor(2.4477)
# Epoch  899 Sharpe:  tensor(2.4477)
# Epoch  900 Sharpe:  tensor(2.4477)
# Epoch  901 Sharpe:  tensor(2.4477)
# Epoch  902 Sharpe:  tensor(2.4477)
# Epoch  903 Sharpe:  tensor(2.4477)
# Epoch  904 Sharpe:  tensor(2.4477)
# Epoch  905 Sharpe:  tensor(2.4477)
# Epoch  906 Sharpe:  tensor(2.4477)
# Epoch  907 Sharpe:  tensor(2.4477)
# Epoch  908 Sharpe:  tensor(2.4477)
# Epoch  909 Sharpe:  tensor(2.4477)
# Epoch  910 Sharpe:  tensor(2.4477)
# Epoch  911 Sharpe:  tensor(2.4477)
# Epoch  912 Sharpe:  tensor(2.4477)
# Epoch  913 Sharpe:  tensor(2.4477)
# Epoch  914 Sharpe:  tensor(2.4477)
# Epoch  915 Sharpe:  tensor(2.4477)
# Epoch  916 Sharpe:  tensor(2.4477)
# Epoch  917 Sharpe:  tensor(2.4477)
# Epoch  918 Sharpe:  tensor(2.4477)
# Epoch  919 Sharpe:  tensor(2.4477)
# Epoch  920 Sharpe:  tensor(2.4477)
# Epoch  921 Sharpe:  tensor(2.4477)
# Epoch  922 Sharpe:  tensor(2.4477)
# Epoch  923 Sharpe:  tensor(2.4477)
# Epoch  924 Sharpe:  tensor(2.4477)
# Epoch  925 Sharpe:  tensor(2.4477)
# Epoch  926 Sharpe:  tensor(2.4477)
# Epoch  927 Sharpe:  tensor(2.4477)
# Epoch  928 Sharpe:  tensor(2.4477)
# Epoch  929 Sharpe:  tensor(2.4477)
# Epoch  930 Sharpe:  tensor(2.4477)
# Epoch  931 Sharpe:  tensor(2.4477)
# Epoch  932 Sharpe:  tensor(2.4477)
# Epoch  933 Sharpe:  tensor(2.4477)
# Epoch  934 Sharpe:  tensor(2.4477)
# Epoch  935 Sharpe:  tensor(2.4477)
# Epoch  936 Sharpe:  tensor(2.4477)
# Epoch  937 Sharpe:  tensor(2.4477)
# Epoch  938 Sharpe:  tensor(2.4477)
# Epoch  939 Sharpe:  tensor(2.4477)
# Epoch  940 Sharpe:  tensor(2.4477)
# Epoch  941 Sharpe:  tensor(2.4477)
# Epoch  942 Sharpe:  tensor(2.4477)
# Epoch  943 Sharpe:  tensor(2.4477)
# Epoch  944 Sharpe:  tensor(2.4477)
# Epoch  945 Sharpe:  tensor(2.4477)
# Epoch  946 Sharpe:  tensor(2.4477)
# Epoch  947 Sharpe:  tensor(2.4477)
# Epoch  948 Sharpe:  tensor(2.4477)
# Epoch  949 Sharpe:  tensor(2.4477)
# Epoch  950 Sharpe:  tensor(2.4477)
# Epoch  951 Sharpe:  tensor(2.4477)
# Epoch  952 Sharpe:  tensor(2.4477)
# Epoch  953 Sharpe:  tensor(2.4477)
# Epoch  954 Sharpe:  tensor(2.4477)
# Epoch  955 Sharpe:  tensor(2.4477)
# Epoch  956 Sharpe:  tensor(2.4477)
# Epoch  957 Sharpe:  tensor(2.4477)
# Epoch  958 Sharpe:  tensor(2.4477)
# Epoch  959 Sharpe:  tensor(2.4477)
# Epoch  960 Sharpe:  tensor(2.4477)
# Epoch  961 Sharpe:  tensor(2.4477)
# Epoch  962 Sharpe:  tensor(2.4477)
# Epoch  963 Sharpe:  tensor(2.4477)
# Epoch  964 Sharpe:  tensor(2.4477)
# Epoch  965 Sharpe:  tensor(2.4477)
# Epoch  966 Sharpe:  tensor(2.4477)
# Epoch  967 Sharpe:  tensor(2.4477)
# Epoch  968 Sharpe:  tensor(2.4477)
# Epoch  969 Sharpe:  tensor(2.4477)
# Epoch  970 Sharpe:  tensor(2.4477)
# Epoch  971 Sharpe:  tensor(2.4477)
# Epoch  972 Sharpe:  tensor(2.4477)
# Epoch  973 Sharpe:  tensor(2.4477)
# Epoch  974 Sharpe:  tensor(2.4477)
# Epoch  975 Sharpe:  tensor(2.4477)
# Epoch  976 Sharpe:  tensor(2.4477)
# Epoch  977 Sharpe:  tensor(2.4477)
# Epoch  978 Sharpe:  tensor(2.4477)
# Epoch  979 Sharpe:  tensor(2.4477)
# Epoch  980 Sharpe:  tensor(2.4477)
# Epoch  981 Sharpe:  tensor(2.4477)
# Epoch  982 Sharpe:  tensor(2.4477)
# Epoch  983 Sharpe:  tensor(2.4477)
# Epoch  984 Sharpe:  tensor(2.4477)
# Epoch  985 Sharpe:  tensor(2.4477)
# Epoch  986 Sharpe:  tensor(2.4477)
# Epoch  987 Sharpe:  tensor(2.4477)
# Epoch  988 Sharpe:  tensor(2.4477)
# Epoch  989 Sharpe:  tensor(2.4477)
# Epoch  990 Sharpe:  tensor(2.4477)
# Epoch  991 Sharpe:  tensor(2.4477)
# Epoch  992 Sharpe:  tensor(2.4477)
# Epoch  993 Sharpe:  tensor(2.4477)
# Epoch  994 Sharpe:  tensor(2.4477)
# Epoch  995 Sharpe:  tensor(2.4477)
# Epoch  996 Sharpe:  tensor(2.4477)
# Epoch  997 Sharpe:  tensor(2.4477)
# Epoch  998 Sharpe:  tensor(2.4477)
# Epoch  999 Sharpe:  tensor(2.4477)
# Cum_return_train tensor(79940.5625, grad_fn=<SelectBackward0>)

# %% [markdown]
# ## 4. Visualization

# %%
plt.rcParams['figure.figsize'] = [7, 3]
# plt.title("sharp's ratio optimization GRURL")
plt.plot(rewards)
# plt.ylim((-0.5,0.5))
# plt.legend(['sharp\'s ratio(GRL):M=25,layer=3'],loc='upper left')
plt.savefig("SRGRL20-3.png", dpi=300)
plt.show()

plt.rcParams['figure.figsize'] = [15, 8]
f, axes = plt.subplots(3, 1, sharex=True)
# plt.suptitle("BTC GRURL Train", fontsize=16)
axes[0].set_ylabel("Prices")
axes[0].plot(prices[M:M+T])
axes[1].set_ylabel("Strategy Returns")
axes[1].plot(Cum_returns.detach().numpy())
axes[2].set_ylabel("Ft")
axes[2].bar(list(range(len(Cum_returns))), Ft[:-1].detach().numpy())
# plt.legend(['Train(GRL):M=25,layer=3'],loc='upper left')
plt.savefig("TrainGRL10-2.png", dpi=300)
plt.show()
df_sharp_train_grurl_10_2 = pd.DataFrame({'sharp_grurl_10_2':np.array(rewards)})
df_sharp_train_grurl_10_2.to_csv(r"./train/sharp_train_grurl_10_2.csv",sep=',')
df_grurl_train_10_2 = pd.DataFrame({'Prices_10_2':prices[M:M+T-1],'Strategy_Returns_10_2':Cum_returns.detach().numpy(),'F_t_10_2':Ft[:-1].detach().numpy()})
df_grurl_train_10_2.to_csv(r"./train/grurl_train_10_2.csv",sep=',')

# %%
# data:M+T:M+T+N+1
prices_test = np.array(raw_prices[1])[OFFSET+M+T:]
# OFFSET = 0 #数据起始点
# M = 25  #输入网络的历史窗口的大小，用于在每个时间步更新权重的历史大小
# T = 2000 #交易者输入的时间序列长度
# N = 600  #验证集大小
# prices_test = np.array(raw_prices[1])[OFFSET+M+T:]
# print(prices[OFFSET+M+T:])
asset_returns_test = asset_returns[:M+N+1]
scaler = StandardScaler()
normalized_asset_returns_test = torch.tensor(scaler.fit_transform(asset_returns_test[:M+N+1][:, None])[:, 0]).to(torch.float32)
# normalized_asset_returns_test = normalized_asset_returns[M+T:T+M+N+1]
# print(asset_returns_test,normalized_asset_returns_test)

rewards_test = []
Ft_test = torch.zeros(N).to(normalized_asset_returns_test.device)
for i in range(1, N):
    data_test = normalized_asset_returns_test[i-1:i+M-1]
    input_test = data_test.view(1,M,1).to(device)
    Ft_test[i] = model(input_test)
    returns_test = miu * (Ft_test[:N-1] * asset_returns_test[M:M+N-1]) - (delta * torch.abs(Ft_test[1:] - Ft_test[:N-1]))
    expected_return_test = torch.mean(returns_test, dim=-1)
    std_return_test = torch.std(returns_test, dim=-1)
    sharpe_test = expected_return_test / (torch.sqrt(std_return_test) + eps)
    rewards_test.append(sharpe_test.detach().cpu())
Cum_return_tests = returns_test.cumsum(dim=-1)
print(Cum_return_tests[-1])
# Out:
# tensor(121.9491, grad_fn=<SelectBackward0>)

# %%
plt.rcParams['figure.figsize'] = [15, 8]
f, axes = plt.subplots(4, 1, sharex=True)
axes[0].set_ylabel("Prices")
axes[0].plot(prices_test[M:M+N+1])
axes[1].set_ylabel("Sharpe ratio")
axes[1].plot(rewards_test)
axes[2].set_ylabel("Strategy Returns")
axes[2].plot(Cum_return_tests.detach().numpy())
axes[3].set_ylabel("Ft")
axes[3].bar(list(range(len(Cum_return_tests))), Ft_test[:-1].detach().numpy())
plt.savefig("TestGRL10-2.png", dpi=300)
plt.show()
df_grurl_test_10_2= pd.DataFrame({'Prices_10_2':prices_test[M:M+N-1],'Strategy_Returns_10_2':Cum_return_tests.detach().numpy(),'F_t_10_2':Ft_test[:-1].detach().numpy()})
df_grurl_test_10_2.to_csv(r"./test/grurl_test_10_2.csv",sep=',')
